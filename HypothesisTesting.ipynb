# %% [markdown]
# # R Tutorial
# Kelly Black
# Department of Mathematics
# 321a Boyd Graduate Studies
# University of Georgia
#
# https://www.cyclismo.org/tutorial/R/hwI.html

# %%
engine = read.csv("enginedata.csv")
head(engine)
# Out:
#   en hc   co    nox
# 1 1  0.50  5.01 1.28
# 2 2  0.65 14.67 0.72
# 3 3  0.46  8.60 1.17
# 4 4  0.41  4.42 1.31
# 5 5  0.41  4.95 1.16
# 6 6  0.39  7.24 1.45

# %%
summary(engine)
# Out:
#        en              hc               co              nox
#  Min.   : 1.00   Min.   :0.3400   Min.   : 1.850   Min.   :0.490
#  1st Qu.:12.75   1st Qu.:0.4375   1st Qu.: 4.388   1st Qu.:1.110
#  Median :24.50   Median :0.5100   Median : 5.905   Median :1.315
#  Mean   :24.00   Mean   :0.5502   Mean   : 7.879   Mean   :1.340
#  3rd Qu.:35.25   3rd Qu.:0.6025   3rd Qu.:10.015   3rd Qu.:1.495
#  Max.   :46.00   Max.   :1.1000   Max.   :23.530   Max.   :2.940

# %% [markdown]
# ## Let's check if the data is normally distributed

# %%
options(repr.plot.width=15, repr.plot.height=10)
hist(engine$co, main="Corbon Monoxide")
boxplot(engine$co,main="Carbon Monoxide")
qqnorm(engine$co,main="Carbon Monoxide")
qqline(engine$co)
# Out:
# Plot with title “Corbon Monoxide”
# Plot with title “Carbon Monoxide”
# Plot with title “Carbon Monoxide”

# %% [markdown]
# ## Let's see if we can get it to be normally distributed

# %%
lengine <- log(engine$co)
boxplot(lengine,main="Carbon Monoxide")
hist(lengine,main="Carbon Monoxide")
qqnorm(lengine,main="QQ Plot for the Log of the Carbon Monoxide")
qqline(lengine)
# Out:
# Plot with title “Carbon Monoxide”
# Plot with title “Carbon Monoxide”
# Plot with title “QQ Plot for the Log of the Carbon Monoxide”

# %% [markdown]
# # Test of Significance
# ### We now perform a test of significance. Here we suppose that ideally the engines should have a mean level of 5.4 and do a two-sided hypothesis test.

# %%
t.test(lengine,mu = log(5.4),alternative = "two.sided")
# Out:
# 	One Sample t-test
#
# data:  lengine
# t = 2.2841, df = 47, p-value = 0.02693
# alternative hypothesis: true mean is not equal to 1.686399
# 95 percent confidence interval:
#  1.709925 2.057431
# sample estimates:
# mean of x
#  1.883678

# %% [markdown]
# # Let's try another T-test with two different groups rather than a target mean value
# ### We'll load a built in data set of weights, with each person having a labeled sex

# %%
data("genderweight", package = "datarium")
head(genderweight)
# Out:
#   id group weight
# 1 1  F     61.58587
# 2 2  F     64.55486
# 3 3  F     66.16888
# 4 4  F     59.30860
# 5 5  F     64.85825
# 6 6  F     65.01211

# %%
res <- t.test(weight ~ group, data = genderweight)
res
# Out:
# 	Welch Two Sample t-test
#
# data:  weight by group
# t = -20.791, df = 26.872, p-value < 2.2e-16
# alternative hypothesis: true difference in means between group F and group M is not equal to 0
# 95 percent confidence interval:
#  -24.53135 -20.12353
# sample estimates:
# mean in group F mean in group M
#        63.49867        85.82612

# %% [markdown]
# ## This t-test compares the two groups and tests if the mean values are equal.  The hypothesis being that the two sexes have different mean weights

# %%
data(iris)
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %% [markdown]
# # Run a t-test to compare the mean Sepal.Length two different iris species

# %%
Sepcies1 <- iris$Sepal.Length[iris$Species == "setosa"]
Sepcies2 <- iris$Sepal.Length[iris$Species == "versicolor"]
t.test(Species1 ~ Species2, data = genderweight)
# Out:
# Error in eval(predvars, data, env): object 'Species1' not found
# Traceback:
#
# 1. t.test(Species1 ~ Species2, data = genderweight)
# 2. t.test.formula(Species1 ~ Species2, data = genderweight)
# 3. eval(m, parent.frame())
# 4. eval(m, parent.frame())
# 5. stats::model.frame(formula = Species1 ~ Species2, data = genderweight)
# 6. model.frame.default(formula = Species1 ~ Species2, data = genderweight)
# 7. eval(predvars, data, env)
# 8. eval(predvars, data, env)

# %%
data("CO2")
head(CO2)
?CO2
